# %%
from xmlrpc.server import SimpleXMLRPCServer

# Function to calculate factorial
def factorial(n):
    if n < 0:
        return "Factorial not defined for negative numbers"
    
    result = 1
    for i in range(1, n + 1):
        result *= i
    
    return result

# Create RPC server
server = SimpleXMLRPCServer(("localhost", 8000))

print("RPC Server is running on port 8000...")

# Register function
server.register_function(factorial, "factorial")

# Run server
server.serve_forever()
# Out:
# RPC Server is running on port 8000...
# 127.0.0.1 - - [04/May/2026 19:12:38] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/May/2026 19:15:04] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [04/May/2026 19:15:18] "POST / HTTP/1.1" 200 -
